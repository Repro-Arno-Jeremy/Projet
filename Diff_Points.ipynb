# %%
import pandas as pd
import matplotlib.pyplot as plt
import os


def diff_points(league):
    df_leagues = pd.DataFrame()
    for league in leagues:
        data = pd.read_csv(os.path.join('data_leagues', league + '.csv'))
        data['forecast_home'] = data['forecast'].apply(lambda x: eval(x))
        data['forecast_away'] = data['forecast'].apply(lambda x: eval(x))
        data['goals'] = data['goals'].apply(lambda x: eval(x))

        data['xP_home'] = data['forecast_home'].apply(lambda f: 3 * float(f['w']) + 1 * float(f['d']))
        data['xP_away'] = data['forecast_away'].apply(lambda f: 3 * float(f['l']) + 1 * float(f['d']))
        data['results'] = data['goals'].apply(lambda f: 3 if float(f['h']) > float(f['a']) else 1 if float(f['h']) == float(f['a']) else 0)
        data['results_away'] = data['goals'].apply(lambda f: 3 if float(f['a']) > float(f['h']) else 1 if float(f['h']) == float(f['a']) else 0)

        results_home = data.groupby('year')['results'].sum()
        results_away = data.groupby('year')['results_away'].sum()
        xp_home = data.groupby('year')['xP_home'].sum()
        xp_away = data.groupby('year')['xP_away'].sum()
        
        df = pd.DataFrame()
        df["diff_points"] = results_home - results_away
        df["diff_points_xp"] = xp_home - xp_away
        df["league"] = league
        df["year"] = df.index
        df.reset_index(drop=True, inplace=True)
        df_leagues = pd.concat([df_leagues, df], ignore_index=True)

    df_leagues.set_index('league', inplace=True)
    df_leagues.set_index('year', append=True, inplace=True)
    return df_leagues
    #.relabel_index(["row 1", "row 2"], axis=0)

def style_formatter(leagues):
    df_leagues = diff_points(leagues)
    return df_leagues.style \
    .format(precision=0, thousands=".", decimal=",") \
    .format_index(str.upper, axis=1) \
    .bar(subset= ["diff_points", "diff_points_xp"], color = ['#b0351a', '#069215'], align=0, vmin=df_leagues["diff_points"].min(), vmax=df_leagues["diff_points"].max(), height=60,
         width=80, props="width: 200px; border-right: 1px solid black;")

leagues = ['La_liga', 'EPL', 'Bundesliga', 'Serie_A', 'RFPL', 'Ligue_1']

style_formatter(leagues)
# Out:
# <style type="text/css">
# #T_d9fc8_row0_col0, #T_d9fc8_row14_col0, #T_d9fc8_row27_col0 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 64.7%, transparent 64.7%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row0_col1 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 71.1%, transparent 71.1%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row1_col0, #T_d9fc8_row12_col0 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 76.3%, transparent 76.3%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row1_col1 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 66.8%, transparent 66.8%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row2_col0 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 73.0%, transparent 73.0%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row2_col1 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 71.9%, transparent 71.9%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row3_col0 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 69.8%, transparent 69.8%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row3_col1 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 76.6%, transparent 76.6%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row4_col0, #T_d9fc8_row20_col0 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 70.7%, transparent 70.7%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row4_col1 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 72.3%, transparent 72.3%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row5_col0, #T_d9fc8_row8_col0 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 74.0%, transparent 74.0%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row5_col1 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 69.1%, transparent 69.1%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row6_col0 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 60.9%, transparent 60.9%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row6_col1 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 55.9%, transparent 55.9%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row7_col0, #T_d9fc8_row9_col0 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 68.4%, transparent 68.4%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row7_col1 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 64.9%, transparent 64.9%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row8_col1 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 75.9%, transparent 75.9%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row9_col1 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 74.5%, transparent 74.5%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row10_col0 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 66.5%, transparent 66.5%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row10_col1 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 71.8%, transparent 71.8%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row11_col0, #T_d9fc8_row48_col0 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 59.1%, transparent 59.1%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row11_col1 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 60.4%, transparent 60.4%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row12_col1 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 63.9%, transparent 63.9%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row13_col0, #T_d9fc8_row31_col0, #T_d9fc8_row52_col1 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 70.2%, transparent 70.2%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row13_col1 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 67.3%, transparent 67.3%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row14_col1, #T_d9fc8_row30_col0 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 60.5%, transparent 60.5%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row15_col0 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 66.0%, transparent 66.0%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row15_col1, #T_d9fc8_row21_col0 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 56.3%, transparent 56.3%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row16_col0 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 35.8%, #b0351a 35.8%, #b0351a 40.0%, transparent 40.0%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row16_col1 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 47.5%, transparent 47.5%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row17_col0 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 55.8%, transparent 55.8%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row17_col1 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 60.7%, transparent 60.7%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row18_col0 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 74.9%, transparent 74.9%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row18_col1 {
#   width: 200px;
#   border-right: 1px solid black;
#   background: linear-gradient(90deg, transparent 40.0%, #069215 40.0%, #069215 64.5%, transparent 64.5%) no-repeat center;
#   background-size: 100% 60.0%;
# }
# #T_d9fc8_row19_col0, #T_d9fc8_row49_col0 {
#   wi

# %%
import scipy.stats as stats

df = diff_points(leagues)

stats.wilcoxon
stats.cohen_d(df["diff_points"], df["diff_points_xp"])

stats.mannwhitneyu(df["diff_points"], df["diff_points_xp"])
# Out:
# MannwhitneyuResult(statistic=1956.0, pvalue=0.41439213688365417)
